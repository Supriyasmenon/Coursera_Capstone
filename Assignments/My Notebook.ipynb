# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Supriya Sundaresan Menon**
#
# Data Scientist

# %% [markdown]
# *I like data science because of the different possibilities to answer many unanswered questions*.

# %% [markdown]
# ### Simple Calculation

# %%
3+4
# Out:
# 7

# %% [markdown]
# 1. First ordered list item
# 2. Another item
#
#
# * Unordered list can use asterisks
# - Or minuses
# + Or pluses
#
#
# | Tables        | Are           |
# | ------------- |:-------------:|
# | col 3 is      | right-aligned |
# | col 2 is      | centered      |
#
#
#
#  [GOOGLE](https://www.google.com) it..!!!
